# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from numpy import arange

# %%
alunos_url16 = 'https://goo.gl/g1sZVa'
alunos16 = pd.read_csv(alunos_url16, sep = ';')

alunos_url15 = 'https://goo.gl/qM1kWH'
alunos15 = pd.read_csv(alunos_url15, sep = ';')

alunos_url14 = 'https://goo.gl/ymRDkb'
alunos14 = pd.read_csv(alunos_url14, sep = ';')

matriculas_url = 'https://bit.ly/2G01rYd'
matriculas = pd.read_csv(matriculas_url, sep = ';')

dados_socioEc_url = 'https://bit.ly/2I5xrMA'
dados_socioec = pd.read_csv(dados_socioEc_url, sep = ';')

cursos_url = 'https://bit.ly/2rwgfc4'
cursos = pd.read_csv(cursos_url, sep = ";")

# %%
alunos_concat = pd.concat([alunos16, alunos15, alunos14])
alunos_concat.dropna(inplace = True)
alunos_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53471 entries, 0 to 20602
# Data columns (total 16 columns):
# matricula               53471 non-null int64
# nome_discente           53471 non-null object
# ano_ingresso            53471 non-null int64
# periodo_ingresso        53471 non-null float64
# forma_ingresso          53471 non-null object
# tipo_discente           53471 non-null object
# status                  53471 non-null object
# sigla_nivel_ensino      53471 non-null object
# nivel_ensino            53471 non-null object
# id_curso                53471 non-null float64
# nome_curso              53471 non-null object
# modalidade_educacao     53471 non-null object
# id_unidade              53471 non-null float64
# nome_unidade            53471 non-null object
# id_unidade_gestora      53471 non-null float64
# nome_unidade_gestora    53471 non-null object
# dtypes: float64(4), int64(2), object(10)
# memory usage: 6.9+ MB

# %%
alunosBTI = alunos_concat[alunos_concat.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"]
alunosCET = alunos_concat[alunos_concat.nome_curso == "CIÊNCIAS E TECNOLOGIA"]

alunosBTI = alunosBTI[~alunosBTI.nome_discente.duplicated()]
alunosCET = alunosCET[~alunosCET.nome_discente.duplicated()]

# %%
num_alunosBTI = alunosBTI.matricula.count()
statusBTI = alunosBTI.status.value_counts()
nome_statusBTI = alunosBTI.status[~alunosBTI.status.duplicated()]

num_alunosCET = alunosCET.matricula.count()
statusCET = alunosCET.status.value_counts()
nome_statusCET = alunosCET.status[~alunosCET.status.duplicated()]

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax1.set_title("Status dos alunos de TI")
bar_position = arange(6)
ax1.bar(bar_position, statusBTI)
ax1.set_xticklabels(nome_statusBTI , rotation = 45)
ax1.set_xticks(range(0,6))

ax2 = fig.add_subplot(1,2,2)
ax2.set_title("Status do alunos de CET")
ax2.bar(bar_position, statusCET)
ax2.set_xticklabels(nome_statusCET, rotation = 45)
ax2.set_xticks(range(0,6))
plt.show()

# %% [markdown]
# limpando tabelas MATRICULA e DADOS SOCIOECONOMICOS

# %%
#matriculas.dropna(inplace=True)
matric_clear = matriculas[~matriculas.discente.duplicated()]
discentes_m = matric_clear.discente
len(discentes_m)
# Out:
# 33682

# %%
#dados_socioec.dropna(inplace=True)
dados_socioec_clear = dados_socioec[~dados_socioec.id_discente.duplicated()]
discentes_s = dados_socioec_clear.id_discente
len(discentes_s)
# Out:
# 10645

# %% [markdown]
# Pegando os discentes iguais nas tabelas

# %%
iguais = []
for i in discentes_m:
    for j in discentes_s:
        if i==j:
            iguais.append(j)
len(iguais)
# Out:
# 5024

# %% [markdown]
# gerando lista com as rows dos discentes iguais na tabela matricula

# %%
lista_id_cursos = []
for i in iguais:
    lista_id_cursos.append(matric_clear[matric_clear.discente == i])v

# %% [markdown]
# percorendo a lista e pegando os id_curso de cada row

# %%
size = len(lista)
lista_cursos = []
for i in range(0, size):
    lista_cursos.append(lista[i]['id_curso'].values[0].astype(int))

# %%
lista_cursos
# Out:
# [5400,
#  4970,
#  4970,
#  111635075,
#  2000032,
#  4970,
#  2000056,
#  2000056,
#  2000056,
#  2000002,
#  2000068,
#  2000068,
#  2000018,
#  1086001,
#  1086001,
#  1086001,
#  1086001,
#  1086001,
#  1086001,
#  1086001,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  4970,
#  315758,
#  118880834,
#  118881115,
#  119512361,
#  119512361,
#  119512361,
#  10320810,
#  7264330,
#  7264330,
#  7264330,
#  7264330,
#  7264330,
#  2000158,
#  2000158,
#  2000158,
#  2000158,
#  2000158,
#  2000158,
#  2000158,
#  2000057,
#  2000158,
#  2000054,
#  2000044,
#  2000044,
#  2000044,
#  2000044,
#  315758,
#  2000026,
#  2000032,
#  2000032,
#  10320810,
#  2000068,
#  2000068,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000066,
#  2000066,
#  2000066,
#  2000066,
#  2000066,
#  2000066,
#  2000066,
#  2000066,
#  2000066,
#  2000066,
#  2000066,
#  6992521,
#  118880834,
#  10345860,
#  6358080,
#  6358080,
#  6358080,
#  2000066,
#  2000066,
#  2000023,
#  2000158,
#  111635069,
#  2000002,
#  2000123,
#  6358080,
#  111635060,
#  111635060,
#  111635060,
#  2000047,
#  2000047,
#  111635060,
#  111635060,
#  111635060,
#  104831949,
#  104831949,
#  104831949,
#  104831949,
#  104831949,
#  2000009,
#  2000009,
#  2000005,
#  2000005,
#  2000005,
#  2000057,
#  118881115,
#  118881115,
#  118881115,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000023,
#  2000058,
#  13027790,
#  13027790,
#  2000058,
#  102160763,
#  102160763,
#  102160763,
#  102160763,
#  102160763,
#  2000031,
#  2000031,
#  2000031,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10345860,
#  10345860,
#  10345860,
#  10345860,
#  2000063,
#  2000042,
#  2000042,
#  111635035,
#  2000011,
#  2000002,
#  2000029,
#  2000032,
#  2000030,
#  2000045,
#  2000025,
#  2000025,
#  2000058,
#  2000039,
#  13027790,
#  2576632,
#  2000025,
#  2000025,
#  118834827,
#  2000016,
#  119512361,
#  2000006,
#  119512361,
#  2000016,
#  2000016,
#  119512361,
#  315785,
#  2000002,
#  2000004,
#  2000004,
#  2000004,
#  2000004,
#  2000004,
#  2000004,
#  2000004,
#  2000004,
#  2000004,
#  2000058,
#  10320810,
#  10320810,
#  10320810,
#  2000011,
#  2000011,
#  2000011,
#  10320810,
#  2000041,
#  1086001,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  111635053,
#  2000022,
#  111635035,
#  111635047,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  118881115,
#  118881115,
#  111635053,
#  118840295,
#  118881115,
#  118881115,
#  118881115,
#  118881115,
#  118881115,
#  2000056,
#  2000056,
#  315757,
#  7410980,
#  7410980,
#  2000058,
#  2000039,
#  2000063,
#  2000063,
#  2000063,
#  2000066,
#  2000066,
#  102160763,
#  102160763,
#  102160763,
#  102160763,
#  102160763,
#  102160763,
#  2000043,
#  2000069,
#  10320810,
#  2000069,
#  2000069,
#  2000069,
#  2000058,
#  2000056,
#  315728,
#  2000056,
#  2000056,
#  2000032,
#  2000058,
#  2000058,
#  2000057,
#  2000057,
#  6633741,
#  2000011,
#  2000002,
#  92127264,
#  2000056,
#  13027790,
#  6358080,
#  6358080,
#  6358080,
#  6358080,
#  2000042,
#  2000056,
#  2000056,
#  2000056,
#  2000002,
#  2000002,
#  10320810,
#  2000056,
#  2000056,
#  111635053,
#  2000057,
#  2000018,
#  2000018,
#  2000018,
#  2000018,
#  2000056,
#  2000121,
#  2000023,
#  2000056,
#  2000056,
#  2000056,
#  2000039,
#  2000039,
#  2000039,
#  2000039,
#  2000023,
#  2000023,
#  111635035,
#  111635053,
#  111635053,
#  111635053,
#  111635053,
#  118881115,
#  2000018,
#  2000018,
#  2000018,
#  2000018,
#  2000018,
#  7191770,
#  4970,
#  4970,
#  5400,
#  2000011,
#  10320810,
#  111635057,
#  111635057,
#  2000158,
#  2000056,
#  2000039,
#  2000039,
#  2000039,
#  2000039,
#  2000039,
#  2000039,
#  2000039,
#  2000039,
#  6358080,
#  2000006,
#  2000016,
#  2000016,
#  2000016,
#  2000016,
#  2000016,
#  2000016,
#  2000016,
#  2000016,
#  2000016,
#  5400,
#  2000002,
#  2000002,
#  10317040,
#  10317040,
#  10317040,
#  2000063,
#  2000063,
#  2000063,
#  2000066,
#  119512361,
#  2000066,
#  2000066,
#  2000066,
#  2000066,
#  2000066,
#  2000023,
#  2000047,
#  2000047,
#  111635060,
#  111635060,
#  111635060,
#  111635060,
#  2000067,
#  2000067,
#  2000023,
#  2000023,
#  2000056,
#  2000056,
#  10320810,
#  10320810,
#  10320810,
#  104831949,
#  104831949,
#  104831949,
#  104831949,
#  104831949,
#  2000042,
#  2000042,
#  2000042,
#  2000016,
#  2000016,
#  2000058,
#  2000058,
#  2000058,
#  2000058,
#  2000058,
#  2000018,
#  2000018,
#  315746,
#  10320810,
#  104831949,
#  2000032,
#  2000032,
#  2000032,
#  2000032,
#  2000032,
#  2000032,
#  2000032,
#  2000032,
#  111635075,
#  2000056,
#  2000056,
#  2000159,
#  10345860,
#  2000150,
#  111635035,
#  111635035,
#  2000057,
#  2000057,
#  2000056,
#  7191770,
#  7191770,
#  7191770,
#  7191770,
#  7191770,
#  7191770,
#  7191770,
#  7191770,
#  7191770,
#  2000068,
#  118922626,
#  10317040,
#  111635038,
#  2000015,
#  2000015,
#  2000015,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  2576632,
#  8068230,
#  2000004,
#  2000004,
#  2000004,
#  2000004,
#  2000004,
#  2000004,
#  2000004,
#  111635075,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  10317040,
#  10317040,
#  10317040,
#  111635035,
#  111635035,
#  111635035,
#  10426760,
#  10426760,
#  10426760,
#  10426760,
#  118880834,
#  2000056,
#  111635057,
#  2000023,
#  111635041,
#  2000022,
#  2000022,
#  111635041,
#  111635041,
#  111635041,
#  111635041,
#  111635041,
#  111635041,
#  111635041,
#  111635041,
#  111635041,
#  111635041,
#  2000068,
#  2000068,
#  2000018,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  2000063,
#  2000063,
#  2000063,
#  2000063,
#  2000063,
#  10320810,
#  10320810,
#  10320810,
#  10317040,
#  2000069,
#  2000034,
#  2000034,
#  111635066,
#  2000030,
#  2000030,
#  2000030,
#  92127264,
#  10320810,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000039,
#  118834827,
#  118834827,
#  118834827,
#  118834827,
#  118834827,
#  118834827,
#  118834827,
#  118834827,
#  2000002,
#  2000002,
#  2000002,
#  2000002,
#  111635057,
#  2000006,
#  6358080,
#  2000056,
#  118834827,
#  2000058,
#  7264330,
#  111635035,
#  111635035,
#  111635035,
#  111635035,
#  111635035,
#  111635035,
#  2000023,
#  2000122,
#  2000056,
#  2000056,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  2000067,
#  2000018,
#  2000018,
#  2000018,
#  104831949,
#  104831949,
#  2000059,
#  2000018,
#  92127264,
#  111635069,
#  92127264,
#  92127264,
#  92127264,
#  2000016,
#  119512361,
#  2000057,
#  2000058,
#  2000058,
#  2000059,
#  2000121,
#  2000042,
#  111635057,
#  10320810,
#  2000030,
#  118834827,
#  111635057,
#  2000002,
#  2000002,
#  2000002,
#  2000002,
#  111635055,
#  111635055,
#  111635055,
#  111635055,
#  2000023,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  2000069,
#  2000069,
#  2000069,
#  111635075,
#  111635075,
#  7264330,
#  2000046,
#  2000006,
#  2000059,
#  2000059,
#  118881115,
#  118840295,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  111635060,
#  104831949,
#  104831949,
#  104831949,
#  2000150,
#  2000029,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  2000123,
#  10320810,
#  10320810,
#  2000055,
#  111635050,
#  111635050,
#  111635050,
#  118922626,
#  118922626,
#  118922626,
#  118922626,
#  118922626,
#  2000011,
#  2000011,
#  2000056,
#  2000005,
#  2000005,
#  92127264,
#  92127264,
#  10320810,
#  2000023,
#  2000056,
#  2000056,
#  2000056,
#  2000056,
#  2000056,
#  2000056,
#  10320810,
#  7264330,
#  118835329,
#  118835329,
#  118835329,
#  118835329,
#  118835329,
#  118835329,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  4970,
#  2000030,
#  2000018,
#  2000018,
#  2000018,
#  2000018,
#  2000018,
#  2000034,
#  2000034,
#  118922026,
#  2000059,
#  2000059,
#  2000002,
#  2000002,
#  2000002,
#  2000002,
#  2000002,
#  2000014,
#  2000058,
#  111635069,
#  2000041,
#  2000045,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000122,
#  2000058,
#  10320810,
#  2576632,
#  2576632,
#  2576632,
#  2576632,
#  2576632,
#  10320810,
#  2000022,
#  2000022,
#  2000022,
#  2000022,
#  2000022,
#  2000022,
#  2000022,
#  2000022,
#  2000040,
#  111635047,
#  10320810,
#  2000015,
#  2000015,
#  2000015,
#  2000015,
#  111635038,
#  118922026,
#  118922026,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  2000030,
#  92127264,
#  92127264,
#  2000122,
#  111635035,
#  2000122,
#  2000063,
#  10426760,
#  2000063,
#  2000063,
#  2000063,
#  2000058,
#  8068230,
#  2000032,
#  2000032,
#  2000032,
#  2000032,
#  2000068,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  2000063,
#  2000063,
#  2000058,
#  2000058,
#  2000058,
#  2000058,
#  2000058,
#  2000058,
#  2000058,
#  2000058,
#  2576623,
#  2000002,
#  2000056,
#  2000014,
#  111635041,
#  92127264,
#  2000063,
#  2000063,
#  1086001,
#  2000034,
#  2000057,
#  2000057,
#  2000056,
#  2000056,
#  2000033,
#  7410980,
#  7410980,
#  7410980,
#  2000012,
#  2000055,
#  2000055,
#  2000055,
#  2000055,
#  2000055,
#  2000014,
#  108227148,
#  2000011,
#  10317040,
#  2000058,
#  2000057,
#  111635069,
#  118880834,
#  118840295,
#  10320810,
#  10320810,
#  118836561,
#  118836561,
#  2000039,
#  2000057,
#  2000056,
#  92127264,
#  92127264,
#  92127264,
#  92127264,
#  2000059,
#  2000057,
#  2000059,
#  2000059,
#  2000059,
#  2000059,
#  2000057,
#  10345860,
#  10345860,
#  10345860,
#  2000023,
#  4970,
#  111635066,
#  111635066,
#  2000121,
#  2000030,
#  2000057,
#  2000057,
#  2000057,
#  2000059,
#  2936390,
#  92127264,
#  92127264,
#  2936390,
#  2936390,
#  2576623,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  2000056,
#  2000032,
#  111635075,
#  104831949,
#  2000121,
#  104831949,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  10320810,
#  2000056,
#  2000056,
#  2000056,
#  2000039,
#  10320810,
#  10320810,
#  104831949,
#  104831949,
#  104831949,
#  104831949,
#  10320810,
#  2000056,
#  2000056,
#  2000056,
#  2000056,
#  2000056,
#  2000056,
#  2000056,
#  2000056,
#  94598200,
#  2000056,
#  111635075,
#  111635075,
#  111635075,
#  111635075,
#  92127264,
#  9295710,
#  92127264,
#  92127264,
#  2000014,
#  6358080,
#  6358080,
#  6358080,
#  2000014,
#  2000045,
#  2000039,
#  2000056,
#  2000056,
#  2000063,
#  2000063,
#  2000063,
#  104831949,
#  104831949,
#  104831949,
#  104831949,
#  104831949,
#  2000057,
#  104831949,
#  104831949,
#  104831949,
#  104831949,
#  2000122,
#  2000122,
#  2000057,
#  92127264,
#  92127264,
#  2000030,
#  92127264,
#  10320810,
#  10320810,
#  104831949,
#  85322571,
#  2576623,
#  2000123,
#  2000123,
#  2000059,
#  2000059,
#  2000057,
#  2000029,
#  2000071,
#  2000071,
#  2000057,
#  2000121,
#  2000121,
#  2000004,
#  2000004,
#  2000004,
#  2000057,
#  2000059,
#  2000009,
#  2000009,
#  111635069,
#  2000045,
#  9300592,
#  ...]

# %% [markdown]
# gerando lista com as rows dos id_cursos iguais na tabela cursos

# %%
#cursos[cursos.id_curso == lista_cursos[4]]
lista_nome_cursos = []
for i in lista_cursos:
    lista_nome_cursos.append(cursos[cursos.id_curso == i])
lista_nome_cursos
# Out:
# [Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns],       id_curso     nome  id_coordenador                      coordenador  \
#  105  111635075  QUÍMICA       5753914.0  FABIANO DO ESPIRITO SANTO GOMES
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  105          ATIVO    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                area_conhecimento tipo_oferta     ...              campus  \
#  105  Ciências Exatas e da Terra     Regular     ...      Campus Central
#
#      id_unidade_responsavel                   unidade_responsavel  \
#  105                    439  CENTRO DE CIÊNCIAS EXATAS E DA TERRA
#
#                                   website  data_funcionamento codigo_inep  \
#  105  http://www.ccet.ufrn.br/hp_quimica/          1970-03-03    312335.0
#
#              dou            portaria_reconhecimento  convenio_academico  \
#  105  2015-12-30  Portaria nº 1098/2015 - DIREG/MEC                 NaN
#
#      Unnamed: 22
#  105         NaN
#
#  [1 rows x 23 columns],     id_curso                nome  id_coordenador  \
#  49   2000032  ENGENHARIA QUÍMICA       5755477.0
#
#                          coordenador situacao_curso nivel_ensino  \
#  49  HUMBERTO NEVES MAIA DE OLIVEIRA          ATIVO    GRADUAÇÃO
#
#     grau_academico modalidade_educacao area_conhecimento tipo_oferta  \
#  49    BACHARELADO          Presencial       Engenharias     Regular
#
#         ...              campus id_unidade_responsavel   unidade_responsavel  \
#  49     ...      Campus Central                    445  CENTRO DE TECNOLOGIA
#
#                     website  data_funcionamento codigo_inep         dou  \
#  49  http://www.eq.ufrn.br/          1974-02-01     12344.0  2016-12-15
#
#         portaria_reconhecimento  convenio_academico Unnamed: 22
#  49  Portaria nº 797/2016 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns],     id_curso      nome  id_coordenador               coordenador  \
#  93   2000056  MEDICINA         22757.0  FRANCISCO PIGNATARO LIMA
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  93          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#      area_conhecimento tipo_oferta     ...              campus  \
#  93  Ciências da Saúde     Regular     ...      Campus Central
#
#     id_unidade_responsavel          unidade_responsavel  \
#  93                    441  CENTRO DE CIÊNCIAS DA SAÚDE
#
#                      website  data_funcionamento codigo_inep         dou  \
#  93  http://prograd.ufrn.br/          1956-03-01     12345.0  2017-12-18
#
#     portaria_reconhecimento  convenio_academico Unnamed: 22
#  93   Portaria MEC nº 1.345                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso      nome  id_coordenador               coordenador  \
#  93   2000056  MEDICINA         22757.0  FRANCISCO PIGNATARO LIMA
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  93          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#      area_conhecimento tipo_oferta     ...              campus  \
#  93  Ciências da Saúde     Regular     ...      Campus Central
#
#     id_unidade_responsavel          unidade_responsavel  \
#  93                    441  CENTRO DE CIÊNCIAS DA SAÚDE
#
#                      website  data_funcionamento codigo_inep         dou  \
#  93  http://prograd.ufrn.br/          1956-03-01     12345.0  2017-12-18
#
#     portaria_reconhecimento  convenio_academico Unnamed: 22
#  93   Portaria MEC nº 1.345                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso      nome  id_coordenador               coordenador  \
#  93   2000056  MEDICINA         22757.0  FRANCISCO PIGNATARO LIMA
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  93          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#      area_conhecimento tipo_oferta     ...              campus  \
#  93  Ciências da Saúde     Regular     ...      Campus Central
#
#     id_unidade_responsavel          unidade_responsavel  \
#  93                    441  CENTRO DE CIÊNCIAS DA SAÚDE
#
#                      website  data_funcionamento codigo_inep         dou  \
#  93  http://prograd.ufrn.br/          1956-03-01     12345.0  2017-12-18
#
#     portaria_reconhecimento  convenio_academico Unnamed: 22
#  93   Portaria MEC nº 1.345                 NaN         NaN
#
#  [1 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns],      id_curso            nome  id_coordenador                coordenador  \
#  109   2000068  SERVIÇO SOCIAL         26160.0  MIRIAM DE OLIVEIRA INACIO
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  109          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#                area_conhecimento tipo_oferta     ...              campus  \
#  109  Ciências Sociais Aplicadas     Regular     ...      Campus Central
#
#      id_unidade_responsavel                   unidade_responsavel  \
#  109                    443  CENTRO DE CIÊNCIAS SOCIAIS APLICADAS
#
#                                                 website  data_funcionamento  \
#  109  http://sol.ccsa.ufrn.br/ccsa/areas/serso/servi...          1945-03-02
#
#      codigo_inep         dou     portaria_reconhecimento  convenio_academico  \
#  109     12325.0  2018-03-02  Portaria Nº 133/2018 - MEC                 NaN
#
#      Unnamed: 22
#  109         NaN
#
#  [1 rows x 23 columns],      id_curso            nome  id_coordenador                coordenador  \
#  109   2000068  SERVIÇO SOCIAL         26160.0  MIRIAM DE OLIVEIRA INACIO
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  109          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#                area_conhecimento tipo_oferta     ...              campus  \
#  109  Ciências Sociais Aplicadas     Regular     ...      Campus Central
#
#      id_unidade_responsavel                   unidade_responsavel  \
#  109                    443  CENTRO DE CIÊNCIAS SOCIAIS APLICADAS
#
#                                                 website  data_funcionamento  \
#  109  http://sol.ccsa.ufrn.br/ccsa/areas/serso/servi...          1945-03-02
#
#      codigo_inep         dou     portaria_reconhecimento  convenio_academico  \
#  109     12325.0  2018-03-02  Portaria Nº 133/2018 - MEC                 NaN
#
#      Unnamed: 22
#  109         NaN
#
#  [1 rows x 23 columns],     id_curso     nome  id_coordenador  \
#  25   2000018  DIREITO       5752486.0
#
#                                            coordenador situacao_curso  \
#  25  ANNA EMANUELLA NELSON DOS SANTOS CAVALCANTI DA...          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  25    GRADUAÇÃO    BACHARELADO          Presencial
#
#               area_conhecimento tipo_oferta     ...              campus  \
#  25  Ciências Sociais Aplicadas     Regular     ...      Campus Central
#
#     id_unidade_responsavel                   unidade_responsavel website  \
#  25                    443  CENTRO DE CIÊNCIAS SOCIAIS APLICADAS     NaN
#
#      data_funcionamento codigo_inep         dou portaria_reconhecimento  \
#  25          1954-01-25     12317.0  2017-07-10         Portaria nº 688
#
#      convenio_academico Unnamed: 22
#  25                 NaN         NaN
#
#  [1 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso      nome  id_coordenador           coordenador situacao_curso  \
#  75  111635060  HISTÓRIA         26221.0  JAILMA MARIA DE LIMA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao area_conhecimento  \
#  75    GRADUAÇÃO   LICENCIATURA          Presencial  Ciências Humanas
#
#     tipo_oferta     ...            campus id_unidade_responsavel  \
#  75     Regular     ...      Campus Caicó                   1482
#
#                       unidade_responsavel                  website  \
#  75  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ  http://prograd.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  75          1974-03-11     12350.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  75  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns],      id_curso                       nome  id_coordenador  \
#  82  118880834  LETRAS - LÍNGUA ESPANHOLA       5753690.0
#
#                              coordenador situacao_curso nivel_ensino  \
#  82  FRANCISCO ERNESTO ZARAGOZA ZALDIVAR          ATIVO    GRADUAÇÃO
#
#     grau_academico modalidade_educacao            area_conhecimento  \
#  82   LICENCIATURA          Presencial  Linguística, Letras e Artes
#
#     tipo_oferta     ...     campus id_unidade_responsavel  \
#  82     Regular     ...        NaN                    442
#
#                             unidade_responsavel website  data_funcionamento  \
#  82  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES     NaN                 NaN
#
#     codigo_inep         dou            portaria_reconhecimento  \
#  82    116564.0  2015-12-30  Portaria nº 1098/2015 - DIREG/MEC
#
#      convenio_academico Unnamed: 22
#  82                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso                        nome  id_coordenador  \
#  84  118881115  LETRAS - LÍNGUA PORTUGUESA       5758252.0
#
#                coordenador situacao_curso nivel_ensino grau_academico  \
#  84  CLEBSON LUIZ DE BRITO          ATIVO    GRADUAÇÃO   LICENCIATURA
#
#     modalidade_educacao area_conhecimento tipo_oferta     ...     campus  \
#  84          Presencial  Ciências Humanas     Regular     ...        NaN
#
#     id_unidade_responsavel                         unidade_responsavel website  \
#  84                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES     NaN
#
#      data_funcionamento codigo_inep         dou  \
#  84                 NaN     31160.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  84  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso                              nome  id_coordenador  \
#  20  119512361  COMUNICAÇÃO SOCIAL - AUDIOVISUAL       5751833.0
#
#             coordenador situacao_curso nivel_ensino grau_academico  \
#  20  MARIA ANGELA PAVAN          ATIVO    GRADUAÇÃO    BACHARELADO
#
#     modalidade_educacao area_conhecimento tipo_oferta     ...     campus  \
#  20          Presencial  Ciências Humanas   Semestral     ...        NaN
#
#     id_unidade_responsavel                         unidade_responsavel website  \
#  20                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES     NaN
#
#      data_funcionamento codigo_inep  dou portaria_reconhecimento  \
#  20                 NaN   1364002.0  NaN                     NaN
#
#      convenio_academico Unnamed: 22
#  20                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso                              nome  id_coordenador  \
#  20  119512361  COMUNICAÇÃO SOCIAL - AUDIOVISUAL       5751833.0
#
#             coordenador situacao_curso nivel_ensino grau_academico  \
#  20  MARIA ANGELA PAVAN          ATIVO    GRADUAÇÃO    BACHARELADO
#
#     modalidade_educacao area_conhecimento tipo_oferta     ...     campus  \
#  20          Presencial  Ciências Humanas   Semestral     ...        NaN
#
#     id_unidade_responsavel                         unidade_responsavel website  \
#  20                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES     NaN
#
#      data_funcionamento codigo_inep  dou portaria_reconhecimento  \
#  20                 NaN   1364002.0  NaN                     NaN
#
#      convenio_academico Unnamed: 22
#  20                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso                              nome  id_coordenador  \
#  20  119512361  COMUNICAÇÃO SOCIAL - AUDIOVISUAL       5751833.0
#
#             coordenador situacao_curso nivel_ensino grau_academico  \
#  20  MARIA ANGELA PAVAN          ATIVO    GRADUAÇÃO    BACHARELADO
#
#     modalidade_educacao area_conhecimento tipo_oferta     ...     campus  \
#  20          Presencial  Ciências Humanas   Semestral     ...        NaN
#
#     id_unidade_responsavel                         unidade_responsavel website  \
#  20                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES     NaN
#
#      data_funcionamento codigo_inep  dou portaria_reconhecimento  \
#  20                 NaN   1364002.0  NaN                     NaN
#
#      convenio_academico Unnamed: 22
#  20                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso                   nome  id_coordenador  \
#  16  10320810  CIÊNCIAS E TECNOLOGIA       5753080.0
#
#                     coordenador situacao_curso nivel_ensino grau_academico  \
#  16  KALINE MELO DE SOUTO VIANA          ATIVO    GRADUAÇÃO    BACHARELADO
#
#     modalidade_educacao           area_conhecimento tipo_oferta     ...      \
#  16          Presencial  Ciências Exatas e da Terra     Regular     ...
#
#     campus id_unidade_responsavel              unidade_responsavel  \
#  16    NaN                   4885  ESCOLA DE CIÊNCIAS E TECNOLOGIA
#
#                         website  data_funcionamento codigo_inep         dou  \
#  16  http://www.prograd.ufrn.br                 NaN    116756.0  2008-06-10
#
#           portaria_reconhecimento  convenio_academico Unnamed: 22
#  16  Resolução nº083/2008-CONSEPE                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso   nome  id_coordenador     coordenador situacao_curso  \
#  22   7264330  DANÇA       5752714.0  MARCOS BRAGATO          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  22    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                area_conhecimento tipo_oferta     ...     campus  \
#  22  Linguística, Letras e Artes     Regular     ...        NaN
#
#     id_unidade_responsavel                         unidade_responsavel  \
#  22                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                       website  data_funcionamento codigo_inep         dou  \
#  22  http://www.cchla.ufrn.br                 NaN    116774.0  2015-10-05
#
#         portaria_reconhecimento  convenio_academico Unnamed: 22
#  22  Portaria nº 699/2015 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso   nome  id_coordenador     coordenador situacao_curso  \
#  22   7264330  DANÇA       5752714.0  MARCOS BRAGATO          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  22    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                area_conhecimento tipo_oferta     ...     campus  \
#  22  Linguística, Letras e Artes     Regular     ...        NaN
#
#     id_unidade_responsavel                         unidade_responsavel  \
#  22                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                       website  data_funcionamento codigo_inep         dou  \
#  22  http://www.cchla.ufrn.br                 NaN    116774.0  2015-10-05
#
#         portaria_reconhecimento  convenio_academico Unnamed: 22
#  22  Portaria nº 699/2015 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso   nome  id_coordenador     coordenador situacao_curso  \
#  22   7264330  DANÇA       5752714.0  MARCOS BRAGATO          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  22    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                area_conhecimento tipo_oferta     ...     campus  \
#  22  Linguística, Letras e Artes     Regular     ...        NaN
#
#     id_unidade_responsavel                         unidade_responsavel  \
#  22                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                       website  data_funcionamento codigo_inep         dou  \
#  22  http://www.cchla.ufrn.br                 NaN    116774.0  2015-10-05
#
#         portaria_reconhecimento  convenio_academico Unnamed: 22
#  22  Portaria nº 699/2015 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso   nome  id_coordenador     coordenador situacao_curso  \
#  22   7264330  DANÇA       5752714.0  MARCOS BRAGATO          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  22    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                area_conhecimento tipo_oferta     ...     campus  \
#  22  Linguística, Letras e Artes     Regular     ...        NaN
#
#     id_unidade_responsavel                         unidade_responsavel  \
#  22                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                       website  data_funcionamento codigo_inep         dou  \
#  22  http://www.cchla.ufrn.br                 NaN    116774.0  2015-10-05
#
#         portaria_reconhecimento  convenio_academico Unnamed: 22
#  22  Portaria nº 699/2015 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso   nome  id_coordenador     coordenador situacao_curso  \
#  22   7264330  DANÇA       5752714.0  MARCOS BRAGATO          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  22    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                area_conhecimento tipo_oferta     ...     campus  \
#  22  Linguística, Letras e Artes     Regular     ...        NaN
#
#     id_unidade_responsavel                         unidade_responsavel  \
#  22                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                       website  data_funcionamento codigo_inep         dou  \
#  22  http://www.cchla.ufrn.br                 NaN    116774.0  2015-10-05
#
#         portaria_reconhecimento  convenio_academico Unnamed: 22
#  22  Portaria nº 699/2015 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso    nome  id_coordenador               coordenador  \
#  111   2000158  TEATRO       5758607.0  MELISSA DOS SANTOS LOPES
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  111          ATIVO    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                 area_conhecimento tipo_oferta     ...              campus  \
#  111  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#      id_unidade_responsavel                         unidade_responsavel  \
#  111                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                               website  data_funcionamento codigo_inep  \
#  111  http://www.cchla.ufrn.br/deart/          2020-01-01    108336.0
#
#              dou     portaria_reconhecimento  convenio_academico Unnamed: 22
#  111  2017-08-07  Portaria nº 847/2017 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso    nome  id_coordenador               coordenador  \
#  111   2000158  TEATRO       5758607.0  MELISSA DOS SANTOS LOPES
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  111          ATIVO    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                 area_conhecimento tipo_oferta     ...              campus  \
#  111  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#      id_unidade_responsavel                         unidade_responsavel  \
#  111                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                               website  data_funcionamento codigo_inep  \
#  111  http://www.cchla.ufrn.br/deart/          2020-01-01    108336.0
#
#              dou     portaria_reconhecimento  convenio_academico Unnamed: 22
#  111  2017-08-07  Portaria nº 847/2017 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso    nome  id_coordenador               coordenador  \
#  111   2000158  TEATRO       5758607.0  MELISSA DOS SANTOS LOPES
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  111          ATIVO    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                 area_conhecimento tipo_oferta     ...              campus  \
#  111  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#      id_unidade_responsavel                         unidade_responsavel  \
#  111                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                               website  data_funcionamento codigo_inep  \
#  111  http://www.cchla.ufrn.br/deart/          2020-01-01    108336.0
#
#              dou     portaria_reconhecimento  convenio_academico Unnamed: 22
#  111  2017-08-07  Portaria nº 847/2017 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso    nome  id_coordenador               coordenador  \
#  111   2000158  TEATRO       5758607.0  MELISSA DOS SANTOS LOPES
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  111          ATIVO    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                 area_conhecimento tipo_oferta     ...              campus  \
#  111  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#      id_unidade_responsavel                         unidade_responsavel  \
#  111                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                               website  data_funcionamento codigo_inep  \
#  111  http://www.cchla.ufrn.br/deart/          2020-01-01    108336.0
#
#              dou     portaria_reconhecimento  convenio_academico Unnamed: 22
#  111  2017-08-07  Portaria nº 847/2017 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso    nome  id_coordenador               coordenador  \
#  111   2000158  TEATRO       5758607.0  MELISSA DOS SANTOS LOPES
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  111          ATIVO    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                 area_conhecimento tipo_oferta     ...              campus  \
#  111  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#      id_unidade_responsavel                         unidade_responsavel  \
#  111                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                               website  data_funcionamento codigo_inep  \
#  111  http://www.cchla.ufrn.br/deart/          2020-01-01    108336.0
#
#              dou     portaria_reconhecimento  convenio_academico Unnamed: 22
#  111  2017-08-07  Portaria nº 847/2017 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso    nome  id_coordenador               coordenador  \
#  111   2000158  TEATRO       5758607.0  MELISSA DOS SANTOS LOPES
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  111          ATIVO    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                 area_conhecimento tipo_oferta     ...              campus  \
#  111  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#      id_unidade_responsavel                         unidade_responsavel  \
#  111                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                               website  data_funcionamento codigo_inep  \
#  111  http://www.cchla.ufrn.br/deart/          2020-01-01    108336.0
#
#              dou     portaria_reconhecimento  convenio_academico Unnamed: 22
#  111  2017-08-07  Portaria nº 847/2017 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso    nome  id_coordenador               coordenador  \
#  111   2000158  TEATRO       5758607.0  MELISSA DOS SANTOS LOPES
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  111          ATIVO    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                 area_conhecimento tipo_oferta     ...              campus  \
#  111  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#      id_unidade_responsavel                         unidade_responsavel  \
#  111                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                               website  data_funcionamento codigo_inep  \
#  111  http://www.cchla.ufrn.br/deart/          2020-01-01    108336.0
#
#              dou     portaria_reconhecimento  convenio_academico Unnamed: 22
#  111  2017-08-07  Portaria nº 847/2017 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso    nome  id_coordenador             coordenador situacao_curso  \
#  96   2000057  MÚSICA       5752855.0  EZEQUIAS OLIVEIRA LIRA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  96    GRADUAÇÃO    BACHARELADO          Presencial
#
#                area_conhecimento tipo_oferta     ...              campus  \
#  96  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#     id_unidade_responsavel unidade_responsavel                      website  \
#  96                    284    ESCOLA DE MÚSICA  http://www.emusica.ufrn.br/
#
#      data_funcionamento codigo_inep         dou     portaria_reconhecimento  \
#  96          2020-01-01     24803.0  2017-08-07  PORTARIA nº 847/2017 - MEC
#
#      convenio_academico Unnamed: 22
#  96                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso    nome  id_coordenador               coordenador  \
#  111   2000158  TEATRO       5758607.0  MELISSA DOS SANTOS LOPES
#
#      situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  111          ATIVO    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                 area_conhecimento tipo_oferta     ...              campus  \
#  111  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#      id_unidade_responsavel                         unidade_responsavel  \
#  111                    442  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                               website  data_funcionamento codigo_inep  \
#  111  http://www.cchla.ufrn.br/deart/          2020-01-01    108336.0
#
#              dou     portaria_reconhecimento  convenio_academico Unnamed: 22
#  111  2017-08-07  Portaria nº 847/2017 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso        nome  id_coordenador                         coordenador  \
#  89   2000054  MATEMÁTICA       5757170.0  ROBERTO TEODORO GURGEL DE OLIVEIRA
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  89          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#               area_conhecimento tipo_oferta     ...              campus  \
#  89  Ciências Exatas e da Terra     Regular     ...      Campus Central
#
#     id_unidade_responsavel                   unidade_responsavel  \
#  89                    439  CENTRO DE CIÊNCIAS EXATAS E DA TERRA
#
#                                  website  data_funcionamento codigo_inep  \
#  89  http://www.ccet.ufrn.br/matematica/          1969-08-01     12333.0
#
#             dou     portaria_reconhecimento  convenio_academico Unnamed: 22
#  89  2016-12-15  Portaria nº 797/2016 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso       nome  id_coordenador                      coordenador  \
#  63   2000044  GEOGRAFIA       5758017.0  SAULO ROBERTO DE OLIVEIRA VITAL
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  63          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#     area_conhecimento tipo_oferta     ...            campus  \
#  63  Ciências Humanas     Regular     ...      Campus Caicó
#
#     id_unidade_responsavel                   unidade_responsavel website  \
#  63                   1482  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ     NaN
#
#      data_funcionamento codigo_inep         dou  \
#  63          1974-03-11   1083438.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  63  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso       nome  id_coordenador                      coordenador  \
#  63   2000044  GEOGRAFIA       5758017.0  SAULO ROBERTO DE OLIVEIRA VITAL
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  63          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#     area_conhecimento tipo_oferta     ...            campus  \
#  63  Ciências Humanas     Regular     ...      Campus Caicó
#
#     id_unidade_responsavel                   unidade_responsavel website  \
#  63                   1482  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ     NaN
#
#      data_funcionamento codigo_inep         dou  \
#  63          1974-03-11   1083438.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  63  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso       nome  id_coordenador                      coordenador  \
#  63   2000044  GEOGRAFIA       5758017.0  SAULO ROBERTO DE OLIVEIRA VITAL
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  63          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#     area_conhecimento tipo_oferta     ...            campus  \
#  63  Ciências Humanas     Regular     ...      Campus Caicó
#
#     id_unidade_responsavel                   unidade_responsavel website  \
#  63                   1482  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ     NaN
#
#      data_funcionamento codigo_inep         dou  \
#  63          1974-03-11   1083438.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  63  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso       nome  id_coordenador                      coordenador  \
#  63   2000044  GEOGRAFIA       5758017.0  SAULO ROBERTO DE OLIVEIRA VITAL
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  63          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#     area_conhecimento tipo_oferta     ...            campus  \
#  63  Ciências Humanas     Regular     ...      Campus Caicó
#
#     id_unidade_responsavel                   unidade_responsavel website  \
#  63                   1482  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ     NaN
#
#      data_funcionamento codigo_inep         dou  \
#  63          1974-03-11   1083438.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  63  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns],     id_curso                      nome  id_coordenador  \
#  39   2000026  ENGENHARIA DE COMPUTAÇÃO       5753097.0
#
#                           coordenador situacao_curso nivel_ensino  \
#  39  DIOGO PINHEIRO FERNANDES PEDROSA          ATIVO    GRADUAÇÃO
#
#     grau_academico modalidade_educacao area_conhecimento tipo_oferta  \
#  39    BACHARELADO          Presencial       Engenharias     Regular
#
#         ...              campus id_unidade_responsavel   unidade_responsavel  \
# ...
#
#      area_conhecimento tipo_oferta     ...              campus  \
#  99  Ciências da Saúde     Regular     ...      Campus Central
#
#     id_unidade_responsavel          unidade_responsavel  \
#  99                    441  CENTRO DE CIÊNCIAS DA SAÚDE
#
#                             website  data_funcionamento codigo_inep  \
#  99  http://www.odonto.dod.ufrn.br/          1947-02-02     12330.0
#
#             dou           portaria_reconhecimento  convenio_academico  \
#  99  2015-01-02  Portaria nº 824/2014 - DIREG/MEC                 NaN
#
#     Unnamed: 22
#  99         NaN
#
#  [1 rows x 23 columns],     id_curso         nome  id_coordenador                         coordenador  \
#  99   2000059  ODONTOLOGIA         26070.0  MARIA CRISTINA DOS SANTOS MEDEIROS
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  99          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#      area_conhecimento tipo_oferta     ...              campus  \
#  99  Ciências da Saúde     Regular     ...      Campus Central
#
#     id_unidade_responsavel          unidade_responsavel  \
#  99                    441  CENTRO DE CIÊNCIAS DA SAÚDE
#
#                             website  data_funcionamento codigo_inep  \
#  99  http://www.odonto.dod.ufrn.br/          1947-02-02     12330.0
#
#             dou           portaria_reconhecimento  convenio_academico  \
#  99  2015-01-02  Portaria nº 824/2014 - DIREG/MEC                 NaN
#
#     Unnamed: 22
#  99         NaN
#
#  [1 rows x 23 columns],     id_curso    nome  id_coordenador             coordenador situacao_curso  \
#  96   2000057  MÚSICA       5752855.0  EZEQUIAS OLIVEIRA LIRA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  96    GRADUAÇÃO    BACHARELADO          Presencial
#
#                area_conhecimento tipo_oferta     ...              campus  \
#  96  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#     id_unidade_responsavel unidade_responsavel                      website  \
#  96                    284    ESCOLA DE MÚSICA  http://www.emusica.ufrn.br/
#
#      data_funcionamento codigo_inep         dou     portaria_reconhecimento  \
#  96          2020-01-01     24803.0  2017-08-07  PORTARIA nº 847/2017 - MEC
#
#      convenio_academico Unnamed: 22
#  96                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso                    nome  id_coordenador  \
#  42   2000029  ENGENHARIA DE PRODUÇÃO       5755045.0
#
#                         coordenador situacao_curso nivel_ensino grau_academico  \
#  42  WERNER KLEYSON DA SILVA SOARES          ATIVO    GRADUAÇÃO    BACHARELADO
#
#     modalidade_educacao area_conhecimento tipo_oferta     ...      \
#  42          Presencial       Engenharias     Regular     ...
#
#              campus id_unidade_responsavel   unidade_responsavel  \
#  42  Campus Central                    445  CENTRO DE TECNOLOGIA
#
#                         website  data_funcionamento codigo_inep         dou  \
#  42  http://www.prograd.ufrn.br          1998-03-03     18853.0  2016-12-15
#
#         portaria_reconhecimento  convenio_academico Unnamed: 22
#  42  Portaria nº 797/2016 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso     nome  id_coordenador       coordenador situacao_curso  \
#  113   2000071  TURISMO       5756776.0  CAROLINA TODESCO          ATIVO
#
#      nivel_ensino grau_academico modalidade_educacao  \
#  113    GRADUAÇÃO    BACHARELADO          Presencial
#
#                area_conhecimento tipo_oferta     ...                    campus  \
#  113  Ciências Sociais Aplicadas     Regular     ...      Campus Currais Novos
#
#      id_unidade_responsavel                   unidade_responsavel website  \
#  113                   1482  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ     NaN
#
#       data_funcionamento codigo_inep         dou     portaria_reconhecimento  \
#  113          2020-01-01    108348.0  2017-04-04  Portaria nº 272/2017 - MEC
#
#       convenio_academico Unnamed: 22
#  113                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso     nome  id_coordenador       coordenador situacao_curso  \
#  113   2000071  TURISMO       5756776.0  CAROLINA TODESCO          ATIVO
#
#      nivel_ensino grau_academico modalidade_educacao  \
#  113    GRADUAÇÃO    BACHARELADO          Presencial
#
#                area_conhecimento tipo_oferta     ...                    campus  \
#  113  Ciências Sociais Aplicadas     Regular     ...      Campus Currais Novos
#
#      id_unidade_responsavel                   unidade_responsavel website  \
#  113                   1482  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ     NaN
#
#       data_funcionamento codigo_inep         dou     portaria_reconhecimento  \
#  113          2020-01-01    108348.0  2017-04-04  Portaria nº 272/2017 - MEC
#
#       convenio_academico Unnamed: 22
#  113                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso    nome  id_coordenador             coordenador situacao_curso  \
#  96   2000057  MÚSICA       5752855.0  EZEQUIAS OLIVEIRA LIRA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  96    GRADUAÇÃO    BACHARELADO          Presencial
#
#                area_conhecimento tipo_oferta     ...              campus  \
#  96  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#     id_unidade_responsavel unidade_responsavel                      website  \
#  96                    284    ESCOLA DE MÚSICA  http://www.emusica.ufrn.br/
#
#      data_funcionamento codigo_inep         dou     portaria_reconhecimento  \
#  96          2020-01-01     24803.0  2017-08-07  PORTARIA nº 847/2017 - MEC
#
#      convenio_academico Unnamed: 22
#  96                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso      nome  id_coordenador         coordenador situacao_curso  \
#  26   2000121  ECOLOGIA       5754633.0  MIRIAM PLAZA PINTO          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao    area_conhecimento  \
#  26    GRADUAÇÃO    BACHARELADO          Presencial  Ciências Biológicas
#
#     tipo_oferta     ...              campus id_unidade_responsavel  \
#  26     Regular     ...      Campus Central                    440
#
#        unidade_responsavel                       website  data_funcionamento  \
#  26  CENTRO DE BIOCIÊNCIAS  http://www.ecologia.ufrn.br/          2003-12-31
#
#     codigo_inep         dou      portaria_reconhecimento  convenio_academico  \
#  26     60286.0  2006-12-08  PORTARIA Nº 1030/2006 - MEC                 NaN
#
#     Unnamed: 22
#  26         NaN
#
#  [1 rows x 23 columns],     id_curso      nome  id_coordenador         coordenador situacao_curso  \
#  26   2000121  ECOLOGIA       5754633.0  MIRIAM PLAZA PINTO          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao    area_conhecimento  \
#  26    GRADUAÇÃO    BACHARELADO          Presencial  Ciências Biológicas
#
#     tipo_oferta     ...              campus id_unidade_responsavel  \
#  26     Regular     ...      Campus Central                    440
#
#        unidade_responsavel                       website  data_funcionamento  \
#  26  CENTRO DE BIOCIÊNCIAS  http://www.ecologia.ufrn.br/          2003-12-31
#
#     codigo_inep         dou      portaria_reconhecimento  convenio_academico  \
#  26     60286.0  2006-12-08  PORTARIA Nº 1030/2006 - MEC                 NaN
#
#     Unnamed: 22
#  26         NaN
#
#  [1 rows x 23 columns],    id_curso           nome  id_coordenador                      coordenador  \
#  0   2000004  ADMINISTRAÇÃO         24415.0  ANDREA CRISTINA SANTOS DE JESUS
#
#    situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  0          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#              area_conhecimento tipo_oferta     ...                    campus  \
#  0  Ciências Sociais Aplicadas     Regular     ...      Campus Currais Novos
#
#    id_unidade_responsavel                   unidade_responsavel website  \
#  0                   1482  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ     NaN
#
#     data_funcionamento codigo_inep         dou     portaria_reconhecimento  \
#  0          1978-09-15     12355.0  2017-04-04  Portaria nº 272/2017 - MEC
#
#     convenio_academico Unnamed: 22
#  0                 NaN         NaN
#
#  [1 rows x 23 columns],    id_curso           nome  id_coordenador                      coordenador  \
#  0   2000004  ADMINISTRAÇÃO         24415.0  ANDREA CRISTINA SANTOS DE JESUS
#
#    situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  0          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#              area_conhecimento tipo_oferta     ...                    campus  \
#  0  Ciências Sociais Aplicadas     Regular     ...      Campus Currais Novos
#
#    id_unidade_responsavel                   unidade_responsavel website  \
#  0                   1482  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ     NaN
#
#     data_funcionamento codigo_inep         dou     portaria_reconhecimento  \
#  0          1978-09-15     12355.0  2017-04-04  Portaria nº 272/2017 - MEC
#
#     convenio_academico Unnamed: 22
#  0                 NaN         NaN
#
#  [1 rows x 23 columns],    id_curso           nome  id_coordenador                      coordenador  \
#  0   2000004  ADMINISTRAÇÃO         24415.0  ANDREA CRISTINA SANTOS DE JESUS
#
#    situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  0          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#              area_conhecimento tipo_oferta     ...                    campus  \
#  0  Ciências Sociais Aplicadas     Regular     ...      Campus Currais Novos
#
#    id_unidade_responsavel                   unidade_responsavel website  \
#  0                   1482  CENTRO DE  ENSINO SUPERIOR DO SERIDÓ     NaN
#
#     data_funcionamento codigo_inep         dou     portaria_reconhecimento  \
#  0          1978-09-15     12355.0  2017-04-04  Portaria nº 272/2017 - MEC
#
#     convenio_academico Unnamed: 22
#  0                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso    nome  id_coordenador             coordenador situacao_curso  \
#  96   2000057  MÚSICA       5752855.0  EZEQUIAS OLIVEIRA LIRA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  96    GRADUAÇÃO    BACHARELADO          Presencial
#
#                area_conhecimento tipo_oferta     ...              campus  \
#  96  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#     id_unidade_responsavel unidade_responsavel                      website  \
#  96                    284    ESCOLA DE MÚSICA  http://www.emusica.ufrn.br/
#
#      data_funcionamento codigo_inep         dou     portaria_reconhecimento  \
#  96          2020-01-01     24803.0  2017-08-07  PORTARIA nº 847/2017 - MEC
#
#      convenio_academico Unnamed: 22
#  96                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso         nome  id_coordenador                         coordenador  \
#  99   2000059  ODONTOLOGIA         26070.0  MARIA CRISTINA DOS SANTOS MEDEIROS
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  99          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#      area_conhecimento tipo_oferta     ...              campus  \
#  99  Ciências da Saúde     Regular     ...      Campus Central
#
#     id_unidade_responsavel          unidade_responsavel  \
#  99                    441  CENTRO DE CIÊNCIAS DA SAÚDE
#
#                             website  data_funcionamento codigo_inep  \
#  99  http://www.odonto.dod.ufrn.br/          1947-02-02     12330.0
#
#             dou           portaria_reconhecimento  convenio_academico  \
#  99  2015-01-02  Portaria nº 824/2014 - DIREG/MEC                 NaN
#
#     Unnamed: 22
#  99         NaN
#
#  [1 rows x 23 columns],     id_curso                 nome  id_coordenador               coordenador  \
#  11   2000009  CIÊNCIAS BIOLÓGICAS         24795.0  RENATA DE FÁTIMA PANOSSO
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  11          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#        area_conhecimento tipo_oferta     ...              campus  \
#  11  Ciências Biológicas     Regular     ...      Campus Central
#
#     id_unidade_responsavel    unidade_responsavel  \
#  11                    440  CENTRO DE BIOCIÊNCIAS
#
#                                                website  data_funcionamento  \
#  11  http://www.cb.ufrn.br/conteudo/cursos/biologia...          1970-02-23
#
#     codigo_inep         dou            portaria_reconhecimento  \
#  11     12332.0  2015-12-30  Portaria nº 1098/2015 - DIREG/MEC
#
#      convenio_academico Unnamed: 22
#  11                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso                 nome  id_coordenador               coordenador  \
#  11   2000009  CIÊNCIAS BIOLÓGICAS         24795.0  RENATA DE FÁTIMA PANOSSO
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  11          ATIVO    GRADUAÇÃO    BACHARELADO          Presencial
#
#        area_conhecimento tipo_oferta     ...              campus  \
#  11  Ciências Biológicas     Regular     ...      Campus Central
#
#     id_unidade_responsavel    unidade_responsavel  \
#  11                    440  CENTRO DE BIOCIÊNCIAS
#
#                                                website  data_funcionamento  \
#  11  http://www.cb.ufrn.br/conteudo/cursos/biologia...          1970-02-23
#
#     codigo_inep         dou            portaria_reconhecimento  \
#  11     12332.0  2015-12-30  Portaria nº 1098/2015 - DIREG/MEC
#
#      convenio_academico Unnamed: 22
#  11                 NaN         NaN
#
#  [1 rows x 23 columns],      id_curso    nome  id_coordenador                       coordenador  \
#  95  111635069  MÚSICA         21707.0  DANILO CESAR GUANAIS DE OLIVEIRA
#
#     situacao_curso nivel_ensino grau_academico modalidade_educacao  \
#  95          ATIVO    GRADUAÇÃO   LICENCIATURA          Presencial
#
#                area_conhecimento tipo_oferta     ...              campus  \
#  95  Linguística, Letras e Artes     Regular     ...      Campus Central
#
#     id_unidade_responsavel unidade_responsavel                      website  \
#  95                    284    ESCOLA DE MÚSICA  http://www.emusica.ufrn.br/
#
#      data_funcionamento codigo_inep         dou  \
#  95          2020-01-01     18395.0  2015-12-30
#
#                portaria_reconhecimento  convenio_academico Unnamed: 22
#  95  Portaria nº 1098/2015 - DIREG/MEC                 NaN         NaN
#
#  [1 rows x 23 columns],     id_curso      nome  id_coordenador        coordenador situacao_curso  \
#  67   2000045  GEOLOGIA         20793.0  HEITOR NEVES MAIA          ATIVO
#
#     nivel_ensino grau_academico modalidade_educacao  \
#  67    GRADUAÇÃO    BACHARELADO          Presencial
#
#               area_conhecimento tipo_oferta     ...              campus  \
#  67  Ciências Exatas e da Terra     Regular     ...      Campus Central
#
#     id_unidade_responsavel                   unidade_responsavel  \
#  67                    439  CENTRO DE CIÊNCIAS EXATAS E DA TERRA
#
#                              website  data_funcionamento codigo_inep  \
#  67  http://www.ccet.ufrn.br/hp_geo/          1976-06-12     12336.0
#
#             dou     portaria_reconhecimento  convenio_academico Unnamed: 22
#  67  2017-08-07  PORTARIA nº 847/2017 - MEC                 NaN         NaN
#
#  [1 rows x 23 columns], Empty DataFrame
#  Columns: [id_curso, nome, id_coordenador, coordenador, situacao_curso, nivel_ensino, grau_academico, modalidade_educacao, area_conhecimento, tipo_oferta, turno, tipo_ciclo_formacao, municipio, campus, id_unidade_responsavel, unidade_responsavel, website, data_funcionamento, codigo_inep, dou, portaria_reconhecimento, convenio_academico, Unnamed: 22]
#  Index: []
#
#  [0 rows x 23 columns], ...]

# %% [markdown]
# percorendo a lista e pegando os nomes dos cursos de cada row

# %%
nomes=[]
size = len(lista_nome_cursos)
for i in range(0,size):
    nomes.append(lista_nome_cursos[i]['nome'].values)
# Out:
# [array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array([], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array([], dtype=object),
#  array(['SERVIÇO SOCIAL'], dtype=object),
#  array(['SERVIÇO SOCIAL'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['LETRAS - LÍNGUA ESPANHOLA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL - AUDIOVISUAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL - AUDIOVISUAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL - AUDIOVISUAL'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['DANÇA'], dtype=object),
#  array(['DANÇA'], dtype=object),
#  array(['DANÇA'], dtype=object),
#  array(['DANÇA'], dtype=object),
#  array(['DANÇA'], dtype=object),
#  array(['TEATRO'], dtype=object),
#  array(['TEATRO'], dtype=object),
#  array(['TEATRO'], dtype=object),
#  array(['TEATRO'], dtype=object),
#  array(['TEATRO'], dtype=object),
#  array(['TEATRO'], dtype=object),
#  array(['TEATRO'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['TEATRO'], dtype=object),
#  array(['MATEMÁTICA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array([], dtype=object),
#  array(['ENGENHARIA DE COMPUTAÇÃO'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['SERVIÇO SOCIAL'], dtype=object),
#  array(['SERVIÇO SOCIAL'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['DESIGN'], dtype=object),
#  array(['LETRAS - LÍNGUA ESPANHOLA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['TEATRO'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array([], dtype=object),
#  array(['ARTES VISUAIS'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['ARQUITETURA E URBANISMO'], dtype=object),
#  array(['ARQUITETURA E URBANISMO'], dtype=object),
#  array(['ARQUITETURA E URBANISMO'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['ENGENHARIA MECÂNICA'], dtype=object),
#  array(['ENGENHARIA MECÂNICA'], dtype=object),
#  array(['ENGENHARIA MECÂNICA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS CONTÁBEIS'], dtype=object),
#  array([], dtype=object),
#  array(['ENGENHARIA DE PRODUÇÃO'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['GEOLOGIA'], dtype=object),
#  array(['ENGENHARIA CIVIL', 'ENGENHARIA CIVIL'], dtype=object),
#  array(['ENGENHARIA CIVIL', 'ENGENHARIA CIVIL'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['AGRONOMIA'], dtype=object),
#  array(['ENGENHARIA CIVIL', 'ENGENHARIA CIVIL'], dtype=object),
#  array(['ENGENHARIA CIVIL', 'ENGENHARIA CIVIL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL - AUDIOVISUAL'], dtype=object),
#  array(['BIBLIOTECONOMIA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL - AUDIOVISUAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL - AUDIOVISUAL'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS CONTÁBEIS'], dtype=object),
#  array(['CIÊNCIAS CONTÁBEIS'], dtype=object),
#  array(['CIÊNCIAS CONTÁBEIS'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['FÍSICA'], dtype=object),
#  array([], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['FILOSOFIA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['LETRAS - INGLÊS'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array([], dtype=object),
#  array(['FONOAUDIOLOGIA'], dtype=object),
#  array(['FONOAUDIOLOGIA'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['TURISMO'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['TURISMO'], dtype=object),
#  array(['TURISMO'], dtype=object),
#  array(['TURISMO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array([], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['CIÊNCIAS ATUARIAIS'], dtype=object),
#  array(['CIÊNCIAS CONTÁBEIS'], dtype=object),
#  array([], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ECOLOGIA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['SISTEMAS DE INFORMAÇÃO'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['CIÊNCIAS CONTÁBEIS'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['TEATRO'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['BIBLIOTECONOMIA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL - AUDIOVISUAL'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['PSICOLOGIA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array([], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['GESTÃO HOSPITALAR'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['ENGENHARIA DE ALIMENTOS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['SISTEMAS DE INFORMAÇÃO'], dtype=object),
#  array(['SISTEMAS DE INFORMAÇÃO'], dtype=object),
#  array(['SISTEMAS DE INFORMAÇÃO'], dtype=object),
#  array(['SISTEMAS DE INFORMAÇÃO'], dtype=object),
#  array(['SISTEMAS DE INFORMAÇÃO'], dtype=object),
#  array(['SISTEMAS DE INFORMAÇÃO'], dtype=object),
#  array(['SISTEMAS DE INFORMAÇÃO'], dtype=object),
#  array(['SISTEMAS DE INFORMAÇÃO'], dtype=object),
#  array(['SISTEMAS DE INFORMAÇÃO'], dtype=object),
#  array(['SERVIÇO SOCIAL'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['CIÊNCIAS SOCIAIS'], dtype=object),
#  array(['CIÊNCIAS SOCIAIS'], dtype=object),
#  array(['CIÊNCIAS SOCIAIS'], dtype=object),
#  array(['CIÊNCIAS SOCIAIS'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['AGRONOMIA'], dtype=object),
#  array(['ENGENHARIA FLORESTAL'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['GESTÃO DE POLÍTICAS PÚBLICAS'], dtype=object),
#  array(['GESTÃO DE POLÍTICAS PÚBLICAS'], dtype=object),
#  array(['GESTÃO DE POLÍTICAS PÚBLICAS'], dtype=object),
#  array(['GESTÃO DE POLÍTICAS PÚBLICAS'], dtype=object),
#  array(['LETRAS - LÍNGUA ESPANHOLA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['SERVIÇO SOCIAL'], dtype=object),
#  array(['SERVIÇO SOCIAL'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['TURISMO'], dtype=object),
#  array(['ESTATÍSTICA'], dtype=object),
#  array(['ESTATÍSTICA'], dtype=object),
#  array(['MATEMÁTICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['BIBLIOTECONOMIA'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['DANÇA'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['BIOMEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL - AUDIOVISUAL'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['ECOLOGIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['GEOGRAFIA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['TURISMO'], dtype=object),
#  array(['TURISMO'], dtype=object),
#  array(['TURISMO'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['DANÇA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['BIBLIOTECONOMIA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - INGLÊS'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['HISTÓRIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ENGENHARIA DE ALIMENTOS'], dtype=object),
#  array(['ENGENHARIA DE PRODUÇÃO'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['ARTES VISUAIS'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['MATEMÁTICA'], dtype=object),
#  array(['FÍSICA'], dtype=object),
#  array(['FÍSICA'], dtype=object),
#  array(['FÍSICA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['LETRAS - LÍNGUA PORTUGUESA'], dtype=object),
#  array(['CIÊNCIAS CONTÁBEIS'], dtype=object),
#  array(['CIÊNCIAS CONTÁBEIS'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ARQUITETURA E URBANISMO'], dtype=object),
#  array(['ARQUITETURA E URBANISMO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['DANÇA'], dtype=object),
#  array(['JORNALISMO'], dtype=object),
#  array(['JORNALISMO'], dtype=object),
#  array(['JORNALISMO'], dtype=object),
#  array(['JORNALISMO'], dtype=object),
#  array(['JORNALISMO'], dtype=object),
#  array(['JORNALISMO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array([], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['DIREITO'], dtype=object),
#  array(['ESTATÍSTICA'], dtype=object),
#  array(['ESTATÍSTICA'], dtype=object),
#  array(['LETRAS - LÍNGUA ESPANHOLA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['CIÊNCIAS ECONÔMICAS'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['FÍSICA'], dtype=object),
#  array(['GEOLOGIA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['BIOMEDICINA'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['AGRONOMIA'], dtype=object),
#  array(['AGRONOMIA'], dtype=object),
#  array(['AGRONOMIA'], dtype=object),
#  array(['AGRONOMIA'], dtype=object),
#  array(['AGRONOMIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['FILOSOFIA'], dtype=object),
#  array(['FILOSOFIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS SOCIAIS'], dtype=object),
#  array(['CIÊNCIAS SOCIAIS'], dtype=object),
#  array(['CIÊNCIAS SOCIAIS'], dtype=object),
#  array(['CIÊNCIAS SOCIAIS'], dtype=object),
#  array(['CIÊNCIAS SOCIAIS'], dtype=object),
#  array(['LETRAS - LÍNGUA ESPANHOLA'], dtype=object),
#  array(['LETRAS - LÍNGUA ESPANHOLA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['BIOMEDICINA'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['BIOMEDICINA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['GESTÃO DE POLÍTICAS PÚBLICAS'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['ENGENHARIA FLORESTAL'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['SERVIÇO SOCIAL'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['ENGENHARIA DE AQUICULTURA'], dtype=object),
#  array([], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['CIÊNCIAS ECONÔMICAS'], dtype=object),
#  array(['EDUCAÇÃO FÍSICA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array([], dtype=object),
#  array(['ESTATÍSTICA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ENGENHARIA TÊXTIL'], dtype=object),
#  array(['FONOAUDIOLOGIA'], dtype=object),
#  array(['FONOAUDIOLOGIA'], dtype=object),
#  array(['FONOAUDIOLOGIA'], dtype=object),
#  array(['CIÊNCIAS CONTÁBEIS'], dtype=object),
#  array(['MATEMÁTICA'], dtype=object),
#  array(['MATEMÁTICA'], dtype=object),
#  array(['MATEMÁTICA'], dtype=object),
#  array(['MATEMÁTICA'], dtype=object),
#  array(['MATEMÁTICA'], dtype=object),
#  array(['CIÊNCIAS ECONÔMICAS'], dtype=object),
#  array([], dtype=object),
#  array(['CIÊNCIAS CONTÁBEIS'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['NUTRIÇÃO'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['LETRAS - LÍNGUA ESPANHOLA'], dtype=object),
#  array(['LETRAS - INGLÊS'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['LETRAS - FRANCÊS'], dtype=object),
#  array(['LETRAS - FRANCÊS'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['FISIOTERAPIA'], dtype=object),
#  array(['ENFERMAGEM'], dtype=object),
#  array([], dtype=object),
#  array(['MATEMÁTICA'], dtype=object),
#  array(['MATEMÁTICA'], dtype=object),
#  array(['ECOLOGIA'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['GEOFÍSICA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['GEOFÍSICA'], dtype=object),
#  array(['GEOFÍSICA'], dtype=object),
#  array(['ENGENHARIA DE AQUICULTURA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ENGENHARIA QUÍMICA'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ECOLOGIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ANÁLISE E DESENVOLVIMENTO DE SISTEMAS'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['QUÍMICA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['CIÊNCIAS ECONÔMICAS'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['ZOOTECNIA'], dtype=object),
#  array(['CIÊNCIAS ECONÔMICAS'], dtype=object),
#  array(['GEOLOGIA'], dtype=object),
#  array(['FARMÁCIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['PEDAGOGIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['BIOMEDICINA'], dtype=object),
#  array(['BIOMEDICINA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['ENGENHARIA ELÉTRICA'], dtype=object),
#  array(['TECNOLOGIA DA INFORMAÇÃO'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['CIÊNCIAS E TECNOLOGIA'], dtype=object),
#  array(['MEDICINA'], dtype=object),
#  array(['ENGENHARIA AMBIENTAL'], dtype=object),
#  array(['ENGENHARIA DE AQUICULTURA'], dtype=object),
#  array(['ARTES VISUAIS'], dtype=object),
#  array(['ARTES VISUAIS'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['ENGENHARIA DE PRODUÇÃO'], dtype=object),
#  array(['TURISMO'], dtype=object),
#  array(['TURISMO'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['ECOLOGIA'], dtype=object),
#  array(['ECOLOGIA'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['ADMINISTRAÇÃO'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['ODONTOLOGIA'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['CIÊNCIAS BIOLÓGICAS'], dtype=object),
#  array(['MÚSICA'], dtype=object),
#  array(['GEOLOGIA'], dtype=object),
#  array([], dtype=object),
#  ...]

# %%
nomes2 = []
for i in range(0,size):
    if len(lista_nome_cursos[i]['nome'].values) > 0:
        nomes2.append(lista_nome_cursos[i]['nome'].values[0])

# %%
nomes_dict = {}
nomes_dict['nomes'] = nomes2
nomes_curso = pd.DataFrame(data=nomes_dict)
nomes_curso
# Out:
#                                              nomes
# 0                                          QUÍMICA
# 1                               ENGENHARIA QUÍMICA
# 2                                         MEDICINA
# 3                                         MEDICINA
# 4                                         MEDICINA
# 5                                   SERVIÇO SOCIAL
# 6                                   SERVIÇO SOCIAL
# 7                                          DIREITO
# 8                                         HISTÓRIA
# 9                                         HISTÓRIA
# 10                                        HISTÓRIA
# 11                                        HISTÓRIA
# 12                                        HISTÓRIA
# 13                                        HISTÓRIA
# 14                                        HISTÓRIA
# 15                                        HISTÓRIA
# 16                                        HISTÓRIA
# 17                                        HISTÓRIA
# 18                                        HISTÓRIA
# 19                                        HISTÓRIA
# 20                                        HISTÓRIA
# 21                                        HISTÓRIA
# 22                       LETRAS - LÍNGUA ESPANHOLA
# 23                      LETRAS - LÍNGUA PORTUGUESA
# 24                COMUNICAÇÃO SOCIAL - AUDIOVISUAL
# 25                COMUNICAÇÃO SOCIAL - AUDIOVISUAL
# 26                COMUNICAÇÃO SOCIAL - AUDIOVISUAL
# 27                           CIÊNCIAS E TECNOLOGIA
# 28                                           DANÇA
# 29                                           DANÇA
# ...                                            ...
# 4815                         CIÊNCIAS E TECNOLOGIA
# 4816                ENGENHARIA DE TELECOMUNICAÇÕES
# 4817                                 ARTES VISUAIS
# 4818                                     PEDAGOGIA
# 4819                                   BIOMEDICINA
# 4820                                   BIOMEDICINA
# 4821                                   BIOMEDICINA
# 4822                            CIÊNCIAS CONTÁBEIS
# 4823                            COMUNICAÇÃO SOCIAL
# 4824                                      ECOLOGIA
# 4825                            COMUNICAÇÃO SOCIAL
# 4826                                     GEOGRAFIA
# 4827                                     PEDAGOGIA
# 4828                                      HISTÓRIA
# 4829        GESTÃO EM SISTEMAS E SERVIÇOS DE SAÚDE
# 4830                                     PEDAGOGIA
# 4831                            COMUNICAÇÃO SOCIAL
# 4832                                 ARTES VISUAIS
# 4833                                      HISTÓRIA
# 4834                                SERVIÇO SOCIAL
# 4835                            CIÊNCIAS CONTÁBEIS
# 4836  COMUNICAÇÃO SOCIAL- PUBLICIDADE E PROPAGANDA
# 4837                                         DANÇA
# 4838                                     AGRONOMIA
# 4839                                     PEDAGOGIA
# 4840                                     PEDAGOGIA
# 4841                                     PEDAGOGIA
# 4842                                SERVIÇO SOCIAL
# 4843                                      MEDICINA
# 4844                                      MEDICINA
#
# [4845 rows x 1 columns]
