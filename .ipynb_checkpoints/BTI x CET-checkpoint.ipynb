# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from numpy import arange
from matplotlib.ticker import FuncFormatter

# %%
alunos_url16 = 'https://goo.gl/g1sZVa'
alunos16 = pd.read_csv(alunos_url16, sep = ';')

# %%
alunos16.dropna(inplace = True)

alunosBTI = alunos16[(alunos16.nome_curso == "TECNOLOGIA DA INFORMAÇÃO") & (alunos16.nivel_ensino == "GRADUAÇÃO")]
alunosCET = alunos16[(alunos16.nome_curso == "CIÊNCIAS E TECNOLOGIA") & (alunos16.nivel_ensino == "GRADUAÇÃO")]

alunosBTI = alunosBTI[~alunosBTI.nome_discente.duplicated()]
alunosCET = alunosCET[~alunosCET.nome_discente.duplicated()]

# %%
statusBTI = alunosBTI.status.value_counts()
#nome_statusBTI = alunosBTI.status[~alunosBTI.status.duplicated()]
nome_statusBTI = statusBTI.keys()

statusCET = alunosCET.status.value_counts()
nome_statusCET = statusCET.keys()

soma = 0
for i in statusBTI:
    soma += i

d = {}

for i, j in enumerate(statusBTI):
    d[i] = j/soma * 100

sBTI = pd.Series(d)

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax1.set_title("Status dos alunos de TI")
bar_position = arange(5)
ax1.bar(bar_position, sBTI, align='center' , color = 'g')
ax1.set_xticklabels(nome_statusBTI , rotation = 45)
ax1.set_xticks(range(0,5))
formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
ax1.yaxis.set_major_formatter(formatter)

soma = 0
for i in statusCET:
    soma += i

d = {}

for i, j in enumerate(statusCET):
    d[i] = j/soma * 100

sCET = pd.Series(d)

ax2 = fig.add_subplot(1,2,2)
ax2.set_title("Status do alunos de CET")
ax2.bar(bar_position, sCET, align='center')
ax2.set_xticklabels(nome_statusCET, rotation = 45)
ax2.set_xticks(range(0,5))
formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
ax2.yaxis.set_major_formatter(formatter)

plt.show()

# %%
turmas161_url = 'https://goo.gl/MFuhNz'
turmas161 = pd.read_csv(turmas161_url, sep = ';')

turmas162_url = 'https://goo.gl/qSDpFe'
turmas162 = pd.read_csv(turmas162_url, sep = ';')

notas161_url = 'https://goo.gl/96o1xn'
notas161 = pd.read_csv(notas161_url, sep = ';')

notas162_url = 'https://goo.gl/uxAJBe'
notas162 = pd.read_csv(notas162_url, sep = ';')

docentes_url = 'https://goo.gl/LdPmyf'
docentes = pd.read_csv(docentes_url, sep = ';')

disciplinas_url = 'https://goo.gl/gBY8eT'
disciplinas = pd.read_csv(disciplinas_url, sep = ';',usecols=["id_componente","codigo","nivel","nome","unidade_responsavel"])

# %%
turmas_concat = pd.concat([turmas161,turmas162])
turmas_concat.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)

turmas_concat.id_componente = turmas_concat.id_componente.astype(str)
disciplinas.dropna(inplace=True)
disciplinas = disciplinas[~disciplinas.id_componente.duplicated()]
disciplinas.head()
# Out:
#   id_componente  codigo nivel                              nome  \
# 0         18643  MUT508     T  COMPOSIÇÃO EM MÚSICA POPULAR III
# 1         18644  MUT516     T                      CO-REPETIÇÃO
# 2         18645  MUT520     T            CONTRABAIXO ACÚSTICO I
# 3         18646  MUT165     T              PIANO COMPLEMENTAR I
# 4         18647  MUT167     T            PIANO COMPLEMENTAR III
#
#   unidade_responsavel
# 0    ESCOLA DE MÚSICA
# 1    ESCOLA DE MÚSICA
# 2    ESCOLA DE MÚSICA
# 3    ESCOLA DE MÚSICA
# 4    ESCOLA DE MÚSICA

# %%
colunas = ["id_turma","codigo","nivel_ensino","nome","unidade_responsavel",
          "situacao_turma","capacidade_aluno","descricao_horario"]

# merge os dois dataframes utilizando como base a coluna id_componenteb
merge_turmas_disciplinas = pd.merge(turmas_concat, disciplinas, on='id_componente')[colunas]

merge_turmas_disciplinas.dropna(inplace=True)
merge_turmas_disciplinas.head()
# Out:
#    id_turma  codigo nivel_ensino                  nome unidade_responsavel  \
# 0  57573186  MUT101      TÉCNICO               CANTO I    ESCOLA DE MÚSICA
# 1  57573319  MUT101      TÉCNICO               CANTO I    ESCOLA DE MÚSICA
# 2  57573320  MUT101      TÉCNICO               CANTO I    ESCOLA DE MÚSICA
# 3  57573321  MUT101      TÉCNICO               CANTO I    ESCOLA DE MÚSICA
# 4  57573187  MUT310      TÉCNICO  APRECIAÇÃO MUSICAL I    ESCOLA DE MÚSICA
#
#   situacao_turma  capacidade_aluno descricao_horario
# 0    CONSOLIDADA               3.0             3T123
# 1    CONSOLIDADA               3.0             5T123
# 2    CONSOLIDADA               3.0             5T456
# 3    CONSOLIDADA               4.0             3T123
# 4       EXCLUÍDA              50.0            4T1234

# %%
turmas_imd = merge_turmas_disciplinas[merge_turmas_disciplinas.codigo.str.contains("IMD")]
turmas_ect = merge_turmas_disciplinas[merge_turmas_disciplinas.codigo.str.contains("ECT")]

turmas_imd = turmas_imd[(turmas_imd.situacao_turma == "CONSOLIDADA") & (turmas_imd.nivel_ensino == "GRADUAÇÃO")]
turmas_imd.capacidade_aluno = turmas_imd.capacidade_aluno.astype(np.int64)

turmas_ect = turmas_ect[(turmas_ect.situacao_turma == "CONSOLIDADA") & (turmas_ect.nivel_ensino == "GRADUAÇÃO")]
turmas_ect.capacidade_aluno = turmas_ect.capacidade_aluno.astype(np.int64)

# %%
notas_concat = pd.concat([notas161,notas162])


colunas = ["APROVADO POR NOTA", "APROVADO", "REPROVADO", "REPROVADO POR MÉDIA E POR FALTAS", "REPROVADO POR NOTA" , "REPROVADO POR FALTAS", "REPROVADO POR NOTA E FALTA"]
notas_imd = notas_concat[(notas_concat.id_turma.isin(turmas_imd.id_turma)) & (notas_concat.descricao.isin(colunas))]
notas_imd_merge = pd.merge(notas_imd, turmas_imd, on = 'id_turma')
del notas_imd_merge['Unnamed: 10']

notas_ect = notas_concat[(notas_concat.id_turma.isin(turmas_ect.id_turma)) & (notas_concat.descricao.isin(colunas))]
notas_ect_merge = pd.merge(notas_ect, turmas_ect, on = 'id_turma')
del notas_ect_merge['Unnamed: 10']

# %%
notas_imd_merge.nome.unique()
# Out:
# array(['PRINCÍPIOS DE LEGISLAÇÃO APLICÁVEIS À TECNOLOGIA DA INFORMAÇÃO E COMUNICAÇÃO DE DADOS',
#        'GESTÃO DE INFRAESTRUTURA DE TI',
#        'INTRODUÇÃO A ORGANIZAÇÃO E ARQUITETURA DE COMPUTADORES',
#        'RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI',
#        'INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO',
#        'PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO',
#        'CÁLCULO DIFERENCIAL E INTEGRAL I', 'CIRCUITOS LÓGICOS',
#        'LABORATÓRIO DE CIRCUITOS LÓGICOS',
#        'ESTRUTURAS DE DADOS BÁSICAS II',
#        'PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS II',
#        'TÓPICOS ESPECIAIS EM SISTEMAS EMBARCADOS A"',
#        'FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I',
#        'ESTRUTURA DE DADOS BÁSICAS I', 'LINGUAGEM DE PROGRAMAÇÃO I',
#        'FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO II',
#        'LINGUAGEM DE PROGRAMAÇÃO II', 'VETORES E GEOMETRIA ANALÍTICA',
#        'PROBABILIDADE', 'SISTEMAS DIGITAIS RECONFIGURÁVEIS',
#        'DESENVOLVIMENTO DE SISTEMAS WEB II', 'PROJETO INTEGRADO II',
#        'TÓPICOS ESPECIAIS EM BIOINFORMÁTICA A"',
#        'PROGRAMAÇÃO COM BANCO DE DADOS', 'SEGURANÇA DA INFORMAÇÃO',
#        'FUNDAMENTOS DE SISTEMAS DE INFORMAÇÃO',
#        'DESIGN DA INTERAÇÃO HUMANO-COMPUTADOR',
#        'AVALIAÇÃO DA INTERAÇÃO HUMANO-COMPUTADOR',
#        'RELAÇÕES ENTRE COMUNICAÇÃO, MÍDIA E EDUCAÇÃO',
#        'PRÁTICAS DE LEITURA EM INGLÊS',
#        'PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS I',
#        'SISTEMAS COLABORATIVOS DE APOIO À APRENDIZAGEM',
#        'FUNDAMENTOS PEDAGÓGICOS PARA A INFORMÁTICA EDUCACIONAL I',
#        'PROCESSOS DE SOFTWARE', 'SISTEMA DE INFORMAÇÃO DISTRIBUÍDO',
#        'TECNOLOGIA DA INFORMAÇÃO E SOCIEDADE', 'REDES DE COMPUTADORES',
#        'ADMINISTRAÇÃO DE SISTEMAS OPERACIONAIS PARA REDES',
#        'TÓPICOS ESPECIAIS EM REDES DE COMPUTADORES A"',
#        'PROJETO INTEGRADO I',
#        'TÉCNICAS DE PROTOTIPAÇÃO E MONTAGEM DE CIRCUITOS E SISTEMAS ELETRÔNICOS',
#        'SISTEMAS EMBARCADOS DE TEMPO REAL',
#        'TEORIA DE CIRCUITOS ELÉTRICOS', 'PROJETO DE INOVAÇÃO TECNOLÓGICA',
#        'DESIGN DE SOFTWARE I', 'INSTRUMENTAÇÃO ELETROELETRÔNICA',
#        'DESIGN DE SOFTWARE II', 'INTRODUÇÃO À GOVERNANÇA E GESTÃO DE TI',
#        'ACESSIBILIDADE DIGITAL', 'EMPREENDEDORISMO',
#        'PROCESSO DE DESENVOLVIMENTO DE SOFTWARE EDUCACIONAL',
#        'INTRODUÇÃO AO TESTE DE SOFTWARE', 'CIRCUITOS ELETRÔNICOS',
#        'PROGRAMAÇÃO CONCORRENTE E DISTRIBUÍDA',
#        'PRÁTICAS DE LEITURA E ESCRITA EM INGLÊS',
#        'TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO IX',
#        'SISTEMAS OPERACIONAIS',
#        'JOGOS DIGITAIS COMO FERRAMENTA PEDAGÓGICA',
#        'INTRODUÇÃO A SISTEMAS DE CONTROLE',
#        'PROCESSAMENTO DIGITAL DE SINAIS',
#        'DESENVOLVIMENTO DE SISTEMAS WEB I',
#        'PROTOCOLO E SERVIÇOS DE INTERNET',
#        'DESENVOLVIMENTO PARA AMBIENTE DESKTOP',
#        'PROJETOS BASEADOS EM MICROCONTROLADORES',
#        'SERVIÇOS DE REDE E TRANSPORTE', 'SEGURANÇA DE REDES',
#        'ADMINISTRAÇÃO DE SERVIÇOS DE REDES PARA INTERNET',
#        'FUNDAMENTOS PEDAGÓGICOS PARA A INFORMÁTICA EDUCACIONAL II',
#        'APRENDIZAGEM BASEADA EM PROJETOS', 'TECNOLOGIAS EDUCACIONAIS',
#        'EDUCAÇÃO A DISTÂNCIA', 'BANCO DE DADOS'], dtype=object)

# %%
notas_ect_merge.nome.unique()
# Out:
# array(['CÁLCULO I', 'MEIO AMBIENTE E DESENVOLVIMENTO URBANO',
#        'EXPRESSÃO GRÁFICA', 'ÁLGEBRA LINEAR', 'ELETRICIDADE APLICADA',
#        'METODOLOGIA CIENTÍFICA E TECNOLÓGICA',
#        'PRÁTICAS DE LEITURA E ESCRITA DE GÊNEROS ACADÊMICOS',
#        'CIÊNCIA E TECNOLOGIA DOS MATERIAIS', 'LÓGICA DE PROGRAMAÇÃO',
#        'INTRODUÇÃO À FÍSICA CLÁSSICA II', 'FÍSICA EXPERIMENTAL II',
#        'COMPUTAÇÃO NUMÉRICA', 'INTRODUÇÃO ÀS ENGENHARIAS',
#        'CIÊNCIA, TECNOLOGIA E SOCIEDADE', 'PROBABILIDADE E ESTATÍSTICA',
#        'INTRODUÇÃO À FÍSICA CLÁSSICA I',
#        'PRÁTICAS DE LEITURA E ESCRITA II',
#        'INTRODUÇÃO À FÍSICA CLÁSSICA III', 'MECÂNICA DOS SÓLIDOS',
#        'MODELAGEM INTEGRADA',
#        'POLÍTICAS E RECURSOS ENERGÉTICOS PARA O DESENVOLVIMENTO SUSTENTÁVEL',
#        'FÍSICA EXPERIMENTAL I',
#        'GESTÃO E ECONOMIA DA CIÊNCIA, TECNOLOGIA E INOVAÇÃO',
#        'PRÉ-CÁLCULO', 'LINGUAGEM DE PROGRAMAÇÃO', 'QUÍMICA GERAL',
#        'PRÁTICAS DE LEITURA E ESCRITA I',
#        'PROTOTIPAGEM MECÂNICA RÁPIDA E DE CIRCUITOS',
#        'PROGRAMAÇÃO ORIENTADA A OBJETOS', 'BANCOS DE DADOS PARA WEB',
#        'CÁLCULO II', 'EQUAÇÕES DIFERENCIAIS',
#        'INSTITUIÇÕES E SERVIÇOS TECNOLÓGICOS', 'GESTÃO DO CONHECIMENTO',
#        'EMPREENDEDORISMO, NEGÓCIOS E GESTÃO DE PROJETOS INOVADORES',
#        'MECÂNICA DOS FLUIDOS', 'MATEMÁTICA FINANCEIRA',
#        'VETORES E GEOMETRIA ANALÍTICA', 'CÁLCULO III',
#        'PRÁTICA DE LEITURA EM INGLÊS',
#        'PRÁTICAS DE LEITURA E ESCRITA DE GÊNEROS ACADÊMICOS EM INGLÊS',
#        'RELAÇÕES DE GÊNERO EM CIÊNCIAS E TECNOLOGIA',
#        'TÓPICOS ESPECIAIS EM DESENVOLVIMENTO SUSTENTÁVEL',
#        'PRÁTICAS DE STARTUP I', 'POLÍTICA CIENTÍFICA E TECNOLÓGICA',
#        'ÉTICA EM CIÊNCIA E TECNOLOGIA',
#        'PROJETOS COM MICROCONTROLADORES E MINICOMPUTADORES',
#        'TÓPICOS EM PRÁTICAS AMBIENTAIS',
#        'FUNDAMENTOS EM DESENVOLVIMENTO SUSTENTÁVEL',
#        'INTELIGÊNCIA ARTIFICIAL E ROBÓTICA: HISTÓRIA E FILOSOFIA',
#        'DIMENSÕES FILOSÓFICAS DA TECNOLOGIA MODERNA',
#        'POLÍTICAS DE GESTÃO EM CIÊNCIA, TECNOLOGIA E INOVAÇÃO',
#        'DESENVOLVIMENTO PARA DISPOSITIVOS MÓVEIS',
#        'DESENVOLVIMENTO DE SISTEMAS PARA INTERNET',
#        'PRÁTICAS DE STARTUP TECNOLÓGICA 1', 'INTERNET DAS COISAS'],
#       dtype=object)

# %%
vga_imd = notas_imd_merge[notas_imd_merge.nome == "VETORES E GEOMETRIA ANALÍTICA"]
vga_imd = vga_imd[~vga_imd.discente.duplicated()]
vga_imd = vga_imd.descricao.value_counts()
nome_vga_imd = vga_imd.keys()

vga_ect = notas_ect_merge[notas_ect_merge.nome == "VETORES E GEOMETRIA ANALÍTICA"]
vga_ect = vga_ect[~vga_ect.discente.duplicated()]
vga_ect = vga_ect.descricao.value_counts()
nome_vga_ect = vga_ect.keys()

calc_imd = notas_imd_merge[notas_imd_merge.nome == "CÁLCULO DIFERENCIAL E INTEGRAL I"]
calc_imd = calc_imd[~calc_imd.discente.duplicated()]
calc_imd = calc_imd.descricao.value_counts()
nome_calc_imd = calc_imd.keys()

calc_ect = notas_ect_merge[notas_ect_merge.nome == "CÁLCULO I"]
calc_ect = calc_ect[~calc_ect.discente.duplicated()]
calc_ect = calc_ect.descricao.value_counts()
nome_calc_ect = calc_ect.keys()

# %%
soma = 0
for i in vga_imd:
    soma += i

d = {}

for i, j in enumerate(vga_imd):
    d[i] = j/soma * 100

vga_BTI = pd.Series(d)

nome = ['REP', 'APRN', 'APR',
       'REPMF', 'REPN']

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(2,2,1)
ax1.set_title("VGA IMD")
bar_position = arange(5)
ax1.bar(bar_position, vga_BTI, align='center' , color = 'g')
ax1.set_xticklabels(nome , rotation = 45)
ax1.set_xticks(range(0,5))
formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
ax1.yaxis.set_major_formatter(formatter)

soma = 0
for i in vga_ect:
    soma += i

d = {}

for i, j in enumerate(vga_ect):
    d[i] = j/soma * 100

vga_CET = pd.Series(d)

ax2 = fig.add_subplot(2,2,2)
ax2.set_title("VGA ECT")
bar_position = arange(5)
ax2.bar(bar_position, vga_CET, align='center' , color = 'g')
ax2.set_xticklabels(nome, rotation = 45)
ax2.set_xticks(range(0,5))
formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
ax2.yaxis.set_major_formatter(formatter)

soma = 0
for i in calc_imd:
    soma += i

d = {}

for i, j in enumerate(calc_imd):
    d[i] = j/soma * 100

calc_BTI = pd.Series(d)

nome = ['REP', 'REPMF', 'APRN', 'APR', 'REPN']

ax3 = fig.add_subplot(2,2,3)
ax3.set_title("CALCULO IMD")
bar_position = arange(5)
ax3.bar(bar_position, calc_BTI, align='center' , color = 'r')
ax3.set_xticklabels(nome , rotation = 45)
ax3.set_xticks(range(0,5))
formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
ax3.yaxis.set_major_formatter(formatter)

soma = 0
for i in calc_ect:
    soma += i

d = {}

for i, j in enumerate(calc_ect):
    d[i] = j/soma * 100

calc_ECT = pd.Series(d)

nome = ['REP', 'APRN', 'APR', 'REPMF','REPN']

ax4 = fig.add_subplot(2,2,4)
ax4.set_title("CALCULO ECT")
bar_position = arange(5)
ax4.bar(bar_position, calc_ECT, align='center' , color = 'r')
ax4.set_xticklabels(nome , rotation = 45)
ax4.set_xticks(range(0,5))
formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
ax4.yaxis.set_major_formatter(formatter)

plt.tight_layout()
plt.show()
